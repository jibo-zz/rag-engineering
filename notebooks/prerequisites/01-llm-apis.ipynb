# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model=os.getenv("OPENAI_MODEL"),
    instructions="You are a helpful assistant.",
    input=[
        {
            "role": "user",
            "content": "Can you print 10 random words?"
        }
    ],
    reasoning={
        "effort": "low"  
    }
)

print(response.output_text)
# Out:
# abruptly, lantern, glacier, velvet, orchard, cipher, horizon, mosaic, thunder, echo

# %%
response.usage
# Out:
# ResponseUsage(input_tokens=24, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=25, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=49)

# %% [markdown]
# ### Google genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model=os.getenv("GEMINI_MODEL"),
    contents=[
        "You are a helpful assistant",
        "Can you print 15 random words?"
        ]

)

print(response.text)
# Out:
# Here are 15 random words for you:
#
# 1.  Cloud
# 2.  Table
# 3.  Whisper
# 4.  Journey
# 5.  Stone
# 6.  Bright
# 7.  Curtain
# 8.  Sparkle
# 9.  Garden
# 10. Quick
# 11. Ocean
# 12. Shadow
# 13. Smile
# 14. Forest
# 15. Quiet

# %% [markdown]
# ### DeepSeek Client

# %%
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv('DEEPSEEK_API_KEY'),
    base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model=os.getenv('DEEPSEEK_MODEL'),
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Can you print 20 random words?"},
    ],
    # stream=False,
    reasoning_effort="low",
    # extra_body={"thinking": {"type": "enabled"}}
)

print(response.choices[0].message.content)
# Out:
# 1. apple
# 2. breeze
# 3. crater
# 4. dolphin
# 5. emerald
# 6. fossil
# 7. galaxy
# 8. horizon
# 9. island
# 10. jungle
# 11. kettle
# 12. lantern
# 13. meadow
# 14. needle
# 15. orbit
# 16. pencil
# 17. quartz
# 18. rocket
# 19. silver
# 20. thunder
